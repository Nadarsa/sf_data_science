# %% [markdown]
# <center> <img src = https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/hh%20label.jpg alt="drawing" style="width:400px;">

# %% [markdown]
# # <center> Проект: Анализ вакансий на hh.ru

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.io as pio
pio.renderers.default = "png"

# %% [markdown]
# # Исследование структуры данных

# %% [markdown]
# 1). Прочитайте данные с помощью библиотеки Pandas. Совет: перед чтением обратите внимание на разделитель внутри файла.

# %%
hh_database = pd.read_csv('data/dst-3.0_16_1_hh_database.csv', sep=';')
print(f'Размерность таблицы равна {hh_database.shape}')
# Out:
# Размерность таблицы равна (44744, 12)

# %% [markdown]
# 2). Выведите несколько первых (последних) строк таблицы, чтобы убедиться в том, что ваши данные не повреждены. Ознакомьтесь с признаками и их структурой.

# %%
display(hh_database.head(3))
display(hh_database.tail(3))
# Out:
#                                    Пол, возраст          ЗП  \
# 0    Мужчина ,  39 лет , родился 27 ноября 1979  29000 руб.
# 1     Мужчина ,  60 лет , родился 20 марта 1959  40000 руб.
# 2  Женщина ,  36 лет , родилась 12 августа 1982  20000 руб.
#
#   Ищет работу на должность:  \
# 0   Системный администратор
# 1      Технический писатель
# 2                  Оператор
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
#
#                                            Занятость  \
# 0  частичная занятость, проектная работа, полная ...
# 1  частичная занятость, проектная работа, полная ...
# 2                                   полная занятость
#
#                                               График  \
# 0  гибкий график, полный день, сменный график, ва...
# 1  гибкий график, полный день, сменный график, уд...
# ...

# %% [markdown]
# 3). Выведите основную информацию о числе непустых значений в столбцах и их типах в таблице.

# %%
display(hh_database.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     44744 non-null  object
#  1   ЗП                               44744 non-null  object
#  2   Ищет работу на должность:        44744 non-null  object
#  3   Город, переезд, командировки     44744 non-null  object
#  4   Занятость                        44744 non-null  object
#  5   График                           44744 non-null  object
#  6   Опыт работы                      44576 non-null  object
#  7   Последнее/нынешнее место работы  44743 non-null  object
#  8   Последняя/нынешняя должность     44742 non-null  object
#  9   Образование и ВУЗ                44744 non-null  object
#  10  Обновление резюме                44744 non-null  object
#  11  Авто                             44744 non-null  object
# ...

# %% [markdown]
# 4). Обратите внимание на информацию о числе непустых значений.

# %%
display(hh_database.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     44744 non-null  object
#  1   ЗП                               44744 non-null  object
#  2   Ищет работу на должность:        44744 non-null  object
#  3   Город, переезд, командировки     44744 non-null  object
#  4   Занятость                        44744 non-null  object
#  5   График                           44744 non-null  object
#  6   Опыт работы                      44576 non-null  object
#  7   Последнее/нынешнее место работы  44743 non-null  object
#  8   Последняя/нынешняя должность     44742 non-null  object
#  9   Образование и ВУЗ                44744 non-null  object
#  10  Обновление резюме                44744 non-null  object
#  11  Авто                             44744 non-null  object
# ...

# %% [markdown]
# 5). Выведите основную статистическую информацию о столбцах.

# %%
display(hh_database.describe())
# Out:
#                                          Пол, возраст          ЗП  \
# count                                           44744       44744
# unique                                          16003         690
# top     Мужчина ,  32 года , родился 17 сентября 1986  50000 руб.
# freq                                               18        4064
#
#        Ищет работу на должность:  \
# count                      44744
# unique                     14929
# top      Системный администратор
# freq                        3099
#
#                              Город, переезд, командировки         Занятость  \
# count                                               44744             44744
# unique                                              10063                38
# top     Москва , не готов к переезду , не готов к кома...  полная занятость
# freq                                                 1261             30026
#
#              График                                        Опыт работы  \
# ...

# %% [markdown]
# # Преобразование данных

# %% [markdown]
# 1). Начнем с простого - с признака **"Образование и ВУЗ"**. Его текущий формат это: **<Уровень образования год выпуска ВУЗ специальность...>**. Например:
# * Высшее образование 2016 Московский авиационный институт (национальный исследовательский университет)...
# * Неоконченное высшее образование 2000  Балтийская государственная академия рыбопромыслового флота…
# Нас будет интересовать только уровень образования.
#
# Создайте с помощью функции-преобразования новый признак **"Образование"**, который должен иметь 4 категории: "высшее", "неоконченное высшее", "среднее специальное" и "среднее".
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак "Образование и ВУЗ".
#
# Совет: обратите внимание на структуру текста в столбце **"Образование и ВУЗ"**. Гарантируется, что текущий уровень образования соискателя всегда находится в первых 2ух слов и начинается с заглавной буквы. Воспользуйтесь этим.
#
# *Совет: проверяйте полученные категории, например, с помощью метода unique()*

# %%
def get_education(education):
    """Функция извлекает уровень образования 
           
    Args:
        education ([object]): строка с образованием, годом выпуска, ВУЗом и специальностью

    Returns:
        [object]: Функция возвращает один из четых уровней образования:  
        ["Высшее", "Неоконченное высшее", "Среднее специальное" и "Среднее"]
        
    """
    education = ' '.join(education.split(' ')[:2])
    
    if 'Высшее образование' in education:
        return 'высшее'
    elif 'Неоконченное высшее' in education:
        return 'неоконченное высшее'
    elif 'Среднее специальное' in education:
        return 'среднее специальное'
    elif 'Среднее образование' in education:
        return 'среднее'
   
hh_database['Образование'] = hh_database['Образование и ВУЗ'].apply(get_education)
#print(hh_database['Образование'].unique())
print(hh_database['Образование'].value_counts())
hh_database = hh_database.drop(['Образование и ВУЗ'], axis=1)
display(hh_database.head())
# Out:
# высшее                 33863
# среднее специальное     5765
# неоконченное высшее     4557
# среднее                  559
# Name: Образование, dtype: int64
#                                    Пол, возраст           ЗП  \
# 0    Мужчина ,  39 лет , родился 27 ноября 1979   29000 руб.
# 1     Мужчина ,  60 лет , родился 20 марта 1959   40000 руб.
# 2  Женщина ,  36 лет , родилась 12 августа 1982   20000 руб.
# 3      Мужчина ,  38 лет , родился 25 июня 1980  100000 руб.
# 4     Женщина ,  26 лет , родилась 3 марта 1993  140000 руб.
#
#                            Ищет работу на должность:  \
# 0                            Системный администратор
# 1                               Технический писатель
# 2                                           Оператор
# 3  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# ...

# %% [markdown]
# 2). Теперь нас интересует столбец **"Пол, возраст"**. Сейчас он представлен в формате **<Пол , возраст , дата рождения >**. Например:
# * Мужчина , 39 лет , родился 27 ноября 1979
# * Женщина , 21 год , родилась 13 января 2000
# Как вы понимаете, нам необходимо выделить каждый параметр в отдельный столбец.
#
# Создайте два новых признака **"Пол"** и **"Возраст"**. При этом важно учесть:
# * Признак пола должен иметь 2 уникальных строковых значения: 'М' - мужчина, 'Ж' - женщина.
# * Признак возраста должен быть представлен целыми числами.
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак **"Пол, возраст"** из таблицы.
#
# *Совет: обратите внимание на структуру текста в столбце, в части на то, как разделены параметры пола, возраста и даты рождения между собой - символом ' , '.
# Гарантируется, что структура одинакова для всех строк в таблице. Вы можете воспользоваться этим.*

# %%
def get_gender(gender):
    """Функция извлекает пол из строки

    Args:
        gender ([object]): строка с указанным полом, возрастом, датой рождения
    
    Returns:
        [object]: Функция возвращает пол ['М', 'Ж']
        
    """
    if 'Мужчина' in gender:
        return 'М'
    else:
        return 'Ж'
    
def get_age(age):
    """Функция извлекает возраст, представленный целым числом

    Args:
        age ([object]): строка с указанным полом, возрастом, датой рождения
    
    Returns:
        [int]: Функция возвращает целочисленный возраст
        
    """
    age_splitted = age.split(' ')
    key_words = ['лет', 'год', 'года']
    for index, value in enumerate(age_splitted):
        if value in key_words:
            return int(age_splitted[index-1])

hh_database['Пол'] = hh_database['Пол, возраст'].apply(get_gender)
hh_database['Возраст'] = hh_database['Пол, возраст'].apply(get_age)
hh_database = hh_database.drop('Пол, возраст', axis=1)
display(hh_database)

print(round(hh_database['Пол'].value_counts(normalize=True)*100, 2))
print(round(hh_database['Возраст'].mean(), 1))
# Out:
#                 ЗП                          Ищет работу на должность:  \
# 0       29000 руб.                            Системный администратор
# 1       40000 руб.                               Технический писатель
# 2       20000 руб.                                           Оператор
# 3      100000 руб.  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4      140000 руб.                  Региональный менеджер по продажам
# ...            ...                                                ...
# 44739   50000 руб.  Финансист, аналитик, экономист, бухгалтер, мен...
# 44740   39000 руб.             Системный администратор, IT-специалист
# 44741   40000 руб.                         Аналитик данных, Математик
# 44742   20000 руб.                                   Контент-менеджер
# 44743  120000 руб.                               Руководитель проекта
#
#                             Город, переезд, командировки  \
# 0      Советск (Калининградская область) , не готов к...
# ...

# %% [markdown]
# 3). Следующим этапом преобразуем признак **"Опыт работы"**. Его текущий формат - это: **<Опыт работы: n лет m месяцев, периоды работы в различных компаниях…>**.
#
# Из столбца нам необходимо выделить общий опыт работы соискателя в месяцах, новый признак назовем "Опыт работы (месяц)"
#
# Для начала обсудим условия решения задачи:
# * Во-первых, в данном признаке есть пропуски. Условимся, что если мы встречаем пропуск, оставляем его как есть (функция-преобразование возвращает NaN)
# * Во-вторых, в данном признаке есть скрытые пропуски. Для некоторых соискателей в столбце стоит значения "Не указано". Их тоже обозначим как NaN (функция-преобразование возвращает NaN)
# * В-третьих, нас не интересует информация, которая описывается после указания опыта работы (периоды работы в различных компаниях)
# * В-четвертых, у нас есть проблема: опыт работы может быть представлен только в годах или только месяцах. Например, можно встретить следующие варианты:
#     * Опыт работы 3 года 2 месяца…
#     * Опыт работы 4 года…
#     * Опыт работы 11 месяцев…
#     * Учитывайте эту особенность в вашем коде
#
# Учитывайте эту особенность в вашем коде
#
# В результате преобразования у вас должен получиться столбец, содержащий информацию о том, сколько месяцев проработал соискатель.
# Выполните преобразование, ответьте на контрольные вопросы и удалите столбец **"Опыт работы"** из таблицы.

# %%
def get_experience(experience):
    """Функция выделяет общий опыт работы соискателя в месяцах

    Args:
        experience ([object]): строка с опятом работы в месяцах и/или годах, а также периоды работы в компаниях
    
    Returns:
        [int]: Функция возвращает опыт работы, выраженный в месяцах
        
    """
    if experience is np.nan or experience == 'Не указано':
        return None
    year_words = ['год', 'года', 'лет']
    month_words = ['месяц', 'месяца', 'месяцев']
    years = 0
    months = 0
    exp_splitted = experience.split(' ')[:7]
    
    for index, value in enumerate(exp_splitted):
        if value in year_words:
            years = int(exp_splitted[index-1])
        if value in month_words:
            months = int(exp_splitted[index-1])
            
    return int(years * 12 + months)

hh_database['Опыт работы (месяц)'] = hh_database['Опыт работы'].apply(get_experience)
hh_database = hh_database.drop('Опыт работы', axis=1)
display(hh_database.head())
print(hh_database['Опыт работы (месяц)'].median())
# Out:
#             ЗП                          Ищет работу на должность:  \
# 0   29000 руб.                            Системный администратор
# 1   40000 руб.                               Технический писатель
# 2   20000 руб.                                           Оператор
# 3  100000 руб.  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4  140000 руб.                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# 3  Саратов , не готов к переезду , готов к редким...
# 4  Москва , не готова к переезду , готова к коман...
#
#                                            Занятость  \
# 0  частичная занятость, проектная работа, полная ...
# 1  частичная занятость, проектная работа, полная ...
# 2                                   полная занятость
# ...

# %% [markdown]
# 4). Хорошо идем! Следующий на очереди признак "Город, переезд, командировки". Информация в нем представлена в следующем виде: **<Город , (метро) , готовность к переезду (города для переезда) , готовность к командировкам>**. В скобках указаны необязательные параметры строки. Например, можно встретить следующие варианты:
#
# * Москва , не готов к переезду , готов к командировкам
# * Москва , м. Беломорская , не готов к переезду, не готов к командировкам
# * Воронеж , готов к переезду (Сочи, Москва, Санкт-Петербург) , готов к командировкам
#
# Создадим отдельные признаки **"Город"**, **"Готовность к переезду"**, **"Готовность к командировкам"**. При этом важно учесть:
#
# * Признак **"Город"** должен содержать только 4 категории: "Москва", "Санкт-Петербург" и "город-миллионник" (их список ниже), остальные обозначьте как "другие".
#
#     Список городов-миллионников:
#
#    <code>million_cities = ['Новосибирск', 'Екатеринбург','Нижний Новгород','Казань', 'Челябинск','Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж','Волгоград']
#     </code>
#     Инфорация о метро, рядом с которым проживает соискатель нас не интересует.
# * Признак **"Готовность к переезду"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к переезду в признаке "Город, переезд, командировки". Например:
#     * … , готов к переезду , …
#     * … , не готова к переезду , …
#     * … , готова к переезду (Москва, Санкт-Петербург, Ростов-на-Дону)
#     * … , хочу переехать (США) , …
#
#     Нас интересует только сам факт возможности или желания переезда.
# * Признак **"Готовность к командировкам"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к командировкам в признаке "Город, переезд, командировки". Например:
#     * … , готов к командировкам , …
#     * … , готова к редким командировкам , …
#     * … , не готов к командировкам , …
#
#     Нас интересует только сам факт готовности к командировке.
#
#     Еще один важный факт: при выгрузки данных у некоторых соискателей "потерялась" информация о готовности к командировкам. Давайте по умолчанию будем считать, что такие соискатели не готовы к командировкам.
#
# Выполните преобразования и удалите столбец **"Город, переезд, командировки"** из таблицы.
#
# *Совет: обратите внимание на то, что структура текста может меняться в зависимости от указания ближайшего метро. Учите это, если будете использовать порядок слов в своей программе.*

# %%
def get_city(city):
    """Функция извлекает город из строки

    Args:
        city ([object]): строка с указанием города, готовности к переездам, готовности к командировкам
    
    Returns:
        [object]: Функция возвращает город из четыре категории:
        "Москва", "Санкт-Петербург" и "город-миллионник", "другие".
        
    """
    city_splitted = city.split(' , ')
    million_cities = ['Новосибирск', 'Екатеринбург', 'Нижний Новгород', 'Казань', 'Челябинск', 'Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж', 'Волгоград']
    if city_splitted[0] == 'Москва':
        return 'Москва'
    elif city_splitted[0] == 'Санкт-Петербург':
        return 'Санкт-Петербург'
    elif city_splitted[0] in million_cities:
        return 'город-миллионник'
    else:
        return 'другие'


def get_moving(move):
    """Функция извлекает готовность/желание переезда

    Args:
        move ([object]): строка с указанием города, готовности к переездам, готовности к командировкам
    
    Returns:
        [bool]: Функция возвращает True или False в зависимости от готовности/желания переезда
        
    """
    if ('не готов к переезду' in move) or ('не готова к переезду' in move) or ('не хочу переехать' in move) or ('не хочу переезжать' in move):
        return False
    else:
        return True
    

def get_business_trips(business_trip):
    """Функция извлекает готовность к командировкам

    Args:
        business_trip ([object]): строка с указанием города, готовности к переездам, готовности к командировкам

    Returns:
        [bool]: Функция возвращает True или False в зависимости от готовности к командировкам
        
    """
    if ('не готов к командировкам' in business_trip) or ('не готова к командировкам' in business_trip) or ('командиров' not in business_trip):
        return False
    else: 
        return True

hh_database['Город'] = hh_database['Город, переезд, командировки'].apply(get_city)
hh_database['Готовность к переезду'] = hh_database['Город, переезд, командировки'].apply(get_moving)
hh_database['Готовность к командировкам'] = hh_database['Город, переезд, командировки'].apply(get_business_trips)
display(hh_database)

mask1 = hh_database['Готовность к переезду'] == True
mask2 = hh_database['Готовность к командировкам'] == True
a = hh_database[mask1 & mask2]['Готовность к командировкам'].count()
b = hh_database.shape[0]
print(f'Процент соискателей, которые готовы одновременно и к переездам, и к командировкам = {round(a/b*100)} %')
# Out:
#                 ЗП                          Ищет работу на должность:  \
# 0       29000 руб.                            Системный администратор
# 1       40000 руб.                               Технический писатель
# 2       20000 руб.                                           Оператор
# 3      100000 руб.  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4      140000 руб.                  Региональный менеджер по продажам
# ...            ...                                                ...
# 44739   50000 руб.  Финансист, аналитик, экономист, бухгалтер, мен...
# 44740   39000 руб.             Системный администратор, IT-специалист
# 44741   40000 руб.                         Аналитик данных, Математик
# 44742   20000 руб.                                   Контент-менеджер
# 44743  120000 руб.                               Руководитель проекта
#
#                             Город, переезд, командировки  \
# 0      Советск (Калининградская область) , не готов к...
# ...

# %% [markdown]
# 5). Рассмотрим поближе признаки **"Занятость"** и **"График"**. Сейчас признаки представляют собой набор категорий желаемой занятости (полная занятость, частичная занятость, проектная работа, волонтерство, стажировка) и желаемого графика работы (полный день, сменный график, гибкий график, удаленная работа, вахтовый метод).
# На сайте hh.ru соискатель может указывать различные комбинации данных категорий, например:
# * полная занятость, частичная занятость
# * частичная занятость, проектная работа, волонтерство
# * полный день, удаленная работа
# * вахтовый метод, гибкий график, удаленная работа, полная занятость
#
# Такой вариант признаков имеет множество различных комбинаций, а значит множество уникальных значений, что мешает анализу. Нужно это исправить!
#
# Давайте создадим признаки-мигалки для каждой категории: если категория присутствует в списке желаемых соискателем, то в столбце на месте строки рассматриваемого соискателя ставится True, иначе - False.
#
# Такой метод преобразования категориальных признаков называется One Hot Encoding и его схема представлена на рисунке ниже:
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/ohe.jpg>
# Выполните данное преобразование для признаков "Занятость" и "График", ответьте на контрольные вопросы, после чего удалите их из таблицы

# %%
employments = ['полная занятость', 'частичная занятость', 'проектная работа', 'волонтерство', 'стажировка']
works_schedule = ['полный день', 'сменный график', 'гибкий график', 'удаленная работа', 'вахтовый метод']

for employment, work_schedule in zip(employments, works_schedule):
    hh_database[employment] = hh_database['Занятость'].apply(lambda x: employment in x)
    hh_database[work_schedule] = hh_database['График'].apply(lambda x: work_schedule in x)

mask1 = hh_database['проектная работа'] == True
mask2 = hh_database['волонтерство'] == True
x1 = hh_database[mask1 & mask2]['волонтерство'].count()
print(f'{x1} людей ищут проектную работу или волонтёрство (в обоих столбцах стоит True)')

mask3 = hh_database['вахтовый метод'] == True
mask4 = hh_database['гибкий график'] == True
x2 = hh_database[mask3 & mask4]['гибкий график'].count()   
print(f'{x2} людей хотят работать вахтовым методом или с гибким графиком (в обоих столбцах стоит True)')

#display(hh_database.head())
hh_database = hh_database.drop(['Занятость', 'График'], axis=1)
display(hh_database.head())
# Out:
# 436 людей ищут проектную работу или волонтёрство (в обоих столбцах стоит True)
# 2311 людей хотят работать вахтовым методом или с гибким графиком (в обоих столбцах стоит True)
#             ЗП                          Ищет работу на должность:  \
# 0   29000 руб.                            Системный администратор
# 1   40000 руб.                               Технический писатель
# 2   20000 руб.                                           Оператор
# 3  100000 руб.  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4  140000 руб.                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# 3  Саратов , не готов к переезду , готов к редким...
# 4  Москва , не готова к переезду , готова к коман...
#
#   Последнее/нынешнее место работы  \
# ...

# %% [markdown]
# 6). (2 балла) Наконец, мы добрались до самого главного и самого важного - признака заработной платы **"ЗП"**.
# В чем наша беда? В том, что помимо желаемой заработной платы соискатель указывает валюту, в которой он бы хотел ее получать, например:
# * 30000 руб.
# * 50000 грн.
# * 550 USD
#
# Нам бы хотелось видеть заработную плату в единой валюте, например, в рублях. Возникает вопрос, а где взять курс валют по отношению к рублю?
#
# На самом деле язык Python имеет в арсенале огромное количество возможностей получения данной информации, от обращения к API Центробанка, до использования специальных библиотек, например pycbrf. Однако, это не тема нашего проекта.
#
# Поэтому мы пойдем в лоб: обратимся к специальным интернет-ресурсам для получения данных о курсе в виде текстовых файлов. Например, MDF.RU, данный ресурс позволяет удобно экспортировать данные о курсах различных валют и акций за указанные периоды в виде csv файлов. Мы уже сделали выгрузку курсов валют, которые встречаются в наших данных за период с 29.12.2017 по 05.12.2019. Скачать ее вы можете **на платформе**
#
# Создайте новый DataFrame из полученного файла. В полученной таблице нас будут интересовать столбцы:
# * "currency" - наименование валюты в ISO кодировке,
# * "date" - дата,
# * "proportion" - пропорция,
# * "close" - цена закрытия (последний зафиксированный курс валюты на указанный день).
#
#
# Перед вами таблица соответствия наименований иностранных валют в наших данных и их общепринятых сокращений, которые представлены в нашем файле с курсами валют. Пропорция - это число, за сколько единиц валюты указан курс в таблице с курсами. Например, для казахстанского тенге курс на 20.08.2019 составляет 17.197 руб. за 100 тенге, тогда итоговый курс равен - 17.197 / 100 = 0.17197 руб за 1 тенге.
# Воспользуйтесь этой информацией в ваших преобразованиях.
#
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/table.jpg>
#
#
# Осталось только понять, откуда брать дату, по которой определяется курс? А вот же она - в признаке **"Обновление резюме"**, в нем содержится дата и время, когда соискатель выложил текущий вариант своего резюме. Нас интересует только дата, по ней бы и будем сопоставлять курсы валют.
#
# Теперь у нас есть вся необходимая информация для того, чтобы создать признак "ЗП (руб)" - заработная плата в рублях.
#
# После ответа на контрольные вопросы удалите исходный столбец заработной платы "ЗП" и все промежуточные столбцы, если вы их создавали.

# %% [markdown]
# Итак, давайте обсудим возможный алгоритм преобразования:
# 1. Перевести признак "Обновление резюме" из таблицы с резюме в формат datetime и достать из него дату. В тот же формат привести признак "date" из таблицы с валютами.
# 2. Выделить из столбца "ЗП" сумму желаемой заработной платы и наименование валюты, в которой она исчисляется. Наименование валюты перевести в стандарт ISO согласно с таблицей выше.
# 3. Присоединить к таблице с резюме таблицу с курсами по столбцам с датой и названием валюты (подумайте, какой тип объединения надо выбрать, чтобы в таблице с резюме сохранились данные о заработной плате, изначально представленной в рублях). Значение close для рубля заполнить единицей 1 (курс рубля самого к себе)
# 4. Умножить сумму желаемой заработной платы на присоединенный курс валюты (close) и разделить на пропорцию (обратите внимание на пропуски после объединения в этих столбцах), результат занести в новый столбец "ЗП (руб)".

# %%
exchange_rates = pd.read_csv('data/ExchangeRates.csv')
exchange_rates['date'] = pd.to_datetime(exchange_rates['date']).dt.date


hh_database['Обновление резюме'] = pd.to_datetime(hh_database['Обновление резюме']).dt.date
hh_database['Дата'] = hh_database['Обновление резюме']

def get_salary(salary):
    """Функция извлекает сумму заработной платы из строки

    Args:
        salary ([object]): строка с размером заработной платы и валюты

    Returns:
        [float]: размер желаемой заработной платы
        
    """
    salary_splitted = salary.split(' ')[0]
    return float(salary_splitted)

def get_currency(currency):
    """Функция извлекает наименование валюты и переводит её в стандарт ISO

    Args:
        currency ([object]): строка с размером заработной платы и валюты

    Returns:
        [object]: наименование валюты желаемой заработной платы в стандарте ISO
        
    """
    currency_splitted = currency.replace('.', '').split(' ')[1]
    currency_dict = {'грн': 'UAH', 'USD': 'USD', 'EUR': 'EUR',
        'белруб': 'BYN', 'KGS': 'KGS','сум': 'UZS', 'AZN': 'AZN', 'KZT': 'KZT', 'руб': 'RUB'
    }
    
    return currency_dict[currency_splitted]

hh_database['Сумма ЗП'] = hh_database['ЗП'].apply(get_salary)
hh_database['Валюта'] = hh_database['ЗП'].apply(get_currency)

#display(hh_database['Валюта'].value_counts())

hh_merged = hh_database.merge(exchange_rates, left_on=['Валюта', 'Дата'], right_on=['currency', 'date'], how='left')
hh_merged['close'] = hh_merged['close'].fillna(1)
hh_merged['proportion'] = hh_merged['proportion'].fillna(1)

hh_merged['ЗП (руб)'] = hh_merged['Сумма ЗП'] * hh_merged['close'] / hh_merged['proportion']

desired_salary = round(hh_merged['ЗП (руб)'].median() / 1000)
print(f'Желаемая медианная заработная плата соискателей (в рублях) равна {desired_salary} тысячам')

hh_merged = hh_merged.drop(['ЗП', 'Сумма ЗП', 'Валюта'], axis=1)
display(hh_merged.info())
# Out:
# Желаемая медианная заработная плата соискателей (в рублях) равна 59 тысячам
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44744 entries, 0 to 44743
# Data columns (total 32 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Ищет работу на должность:        44744 non-null  object
#  1   Город, переезд, командировки     44744 non-null  object
#  2   Последнее/нынешнее место работы  44743 non-null  object
#  3   Последняя/нынешняя должность     44742 non-null  object
#  4   Обновление резюме                44744 non-null  object
#  5   Авто                             44744 non-null  object
#  6   Образование                      44744 non-null  object
#  7   Пол                              44744 non-null  object
#  8   Возраст                          44744 non-null  int64
#  9   Опыт работы (месяц)              44574 non-null  float64
# ...

# %% [markdown]
# # Исследование зависимостей в данных

# %% [markdown]
# 1). Постройте распределение признака **"Возраст"**. Опишите распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится возраст большинства соискателей? Есть ли аномалии для признака возраста, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 4))
histplot = sns.histplot(data=hh_merged, x='Возраст', ax=axes[0]);
histplot.set_title('Гистрограмма распределение возраста');
histplot.set_ylabel('Число соискателей') 
boxplot = sns.boxplot(data=hh_merged, x='Возраст', ax=axes[1]);
boxplot.set_title('Коробчатая диаграмма распределения возраста');

print(hh_merged['Возраст'].mode()[0])
print(hh_merged['Возраст'].min())
print(hh_merged['Возраст'].quantile([0.25, 0.75]))
# Out:
# 30
# 14
# 0.25    27.0
# 0.75    36.0
# Name: Возраст, dtype: float64

# %% [markdown]
# Анализируя гистограмму распределения возраста соискателей, а также пользуясь графиком коробчатой диаграммы, можно сделать следующие выводы.
# 1.) Мода распределения равна 30. Предельные значения признака составляют примерно 14 и 50 лет (согласно "усам" коробчатой диаграмме). Возраст большиства соискателей согласно коробчатой диаграмме находится приблизительно в интервале от 27 до 36 лет. В данных присутсвуют анамалии, например, возраст соискателей, превышающий пенсионный возраст - в среднем 60 лет -, а также выбросы признака свыше 70 лет в области 80-ти и 100-а лет. Вид распределения согласно графику гистограммы напоминает логнормальное распределение.
# 2.) Итак, обобщая математические зависимости, можно утверждать, что признак распределен относительно логнормально, с модой, равной 30-ти годам, то есть наибольшая чать соискателей это молодые люди. В распределении минимум начинается в возврасте 14 лет, что вполне может быть связано с сезонной подработкой подростков, а также рядом некоторых профессий, например, сферы кинематографии. По графика определяются выбросы с возрастом соискателей, превышающих пенсионный возраст.
# 3.) Можно предположить, что наибольшая частота соискателей в возрасте 30 лет связана со сменой работы в поисках лучших для себя условий. Большинство соискателей в возрасте от 27 до 36 лет также вероятно всего ищут для себя новую работу с целью получения более значимой должности, большей зарплаты, соц.пакета, близости к дому и прочее, или же они могут желать сменить профессию на что-то смежное или же диаметрально противоположное. Выбросы, отмеченные на коробчатой диаграмме в интервале от 50 до 60 лет примерно, сложно однозначно считать таковыми, т.к. люди предпенионного и даже пенсионного возраста могут работать и как следствие искать работу. А вот возраст соискателей приближающийся к 70 годам и выше, особенно 80-100 лет, заставляет сделать выводы о таковом возрасте как об анамальных значениях.

# %% [markdown]
# 2). Постройте распределение признака **"Опыт работы (месяц)"**. Опишите данное распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится опыт работы большинства соискателей? Есть ли аномалии для признака возраста, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 4))
histplot = sns.histplot(data=hh_merged, x='Опыт работы (месяц)', ax=axes[0]);
histplot.set_title('Гистрограмма распределение опыта работы в месяцах');
histplot.set_ylabel('Число соискателей') 
boxplot = sns.boxplot(data=hh_merged, x='Опыт работы (месяц)', ax=axes[1]);
boxplot.set_title('Коробчатая диаграмма распределения опыта работы в месяцах');

print(hh_merged['Опыт работы (месяц)'].mode()[0])
print(hh_merged['Опыт работы (месяц)'].max())
print(hh_merged['Опыт работы (месяц)'].quantile([0.25, 0.75]))
# Out:
# 81.0
# 1188.0
# 0.25     57.0
# 0.75    154.0
# Name: Опыт работы (месяц), dtype: float64

# %% [markdown]
# Анализируя гистограмму распределения возраста соискателей, а также пользуясь графиком коробчатой диаграммы, можно сделать следующие выводы.
# 1.) Мода распределения равна 81. Пределельные значения примерно равны согласно "усам" коробчатой диаграммы 0 и 300. Опыт работы большинства соискателей находится примерно в интервале от 50 до 150 месяцев. Согласно гистограмме распределения признака и коробчатой диаграмме регистрируются потенциальные выбросы, начиная примерно с 250 месяцев, однако всё, что идет до 600 мес. (50 лет), я бы предварительно приняла в качестве "нормальных" данных (однако требуется дополнительный анализ на стыковку опыта работы и возраста), а вот всё, что свыше 600 мес., в особенности выброс близ 1200 (сопоставимый с продолжительностью жизни долгожителя...) - стоит однозначно считать аномалиями. Вид распределения согласно графику гистограммы напоминает логнормальное распределение.
# 2.) Обобщая математические зависимости, можно говорить о наличии выбросов опыта работы, начиная как минимум с 600 мес. Однако определение границы выбросов требует доп.анализа на корреляцию с возрастом соискателей.
# 3.) Мода распределения, равная 81 мес., примерно 7 годам, является адекватной и вполне коррелируется модальным возрастом из предыдущего задания. Интервал опыта работы большиснтва сооскателей также адекватен. А вот наличие выбросов со столь причудливым опытом работы можно объяснить человеческим фактором, желанием добавить себе "немного" опыта, обычной опечаткой и неточностями в составлении резюме.

# %% [markdown]
# 3). Постройте распределение признака **"ЗП (руб)"**. Опишите данное распределение, отвечая на следующие вопросы: каковы предельные значения признака, в каком примерном интервале находится заработная плата большинства соискателей? Есть ли аномалии для признака возраста? Обратите внимание на гигантские размеры желаемой заработной платы.
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 4))
histplot = sns.histplot(data=hh_merged, x='ЗП (руб)', ax=axes[0]);
histplot.set_title('Гистрограмма распределение размера зарплаты в рублях');
histplot.set_ylabel('Число соискателей') 
boxplot = sns.boxplot(data=hh_merged, x='ЗП (руб)', ax=axes[1]);
boxplot.set_title('Коробчатая диаграмма распределения размера зарплаты в рублях');

print(hh_merged['ЗП (руб)'].mode()[0])
#print(hh_merged['ЗП (руб)'].min())
#print(hh_merged['ЗП (руб)'].max())
#print(hh_merged['ЗП (руб)'].quantile([0.25, 0.75]))

fig = px.histogram(
    data_frame=hh_merged,
    x = 'ЗП (руб)',
    title='Гистрограмма распределение размера зарплаты в рублях',
    
)
fig.show()

fig = px.box(
    data_frame=hh_merged,
    x = 'ЗП (руб)',
    title='Коробчатая диаграмма распределения размера зарплаты в рублях'
)
fig.show()
# Out:
# 50000.0

# %% [markdown]
# Анализируя гистограмму распределения возраста соискателей, а также пользуясь графиком коробчатой диаграммы, можно сделать следующие выводы.
# 1.) Мода распределения равна 50 000 руб. Предельные значения признака согласно "усам" коробчатой диаграммы приближенно равны 1 и 181 000 руб. При этом заработная плата большинства соискателей примерно находится в интервале от 37 000 до 95 000 руб. Что касается выбросов, то они безусловно присутствуют в данном признаке. Этот факт читается невооруженным глазом как на гистограмме, так и на коробчатой диаграмме - графики буквально сплюснуты под весом выбросов. Бросается в глаза крайняя правая точка на коробчатой диаграмме, соответствующая 24 304 876.0 руб. Вопрос определения, с какого размера считать размер зарплаты аномальным, весьма субъективен и зависит от ряда факторов, в том числе сферы деятельности, профессии. Однако в рамках данного проекта, отнесем к выбросам заработные платы, размер которых превышает 1 млн.
# 2.) Обобщая математические зависимости, можно сделать ключевой вывод, что признак заработной платы в рублях имеет выбросы, причем величины некоторых аномалий весьма огромны, что безусловно загрязняет имеющиеся данные и требует очистки и обработки.
# 3.) Если говорить о причинах такой загрязненность данных и наличии гиганстких выбросов, то здесь имеет место как банальная опечатка, ошибка при введении информации и заполнении резюме, так и преднамеренное действие, выраженное, например, в шутке или же в высоком мнении о своих профессиональных возможностях.

# %% [markdown]
# 4). Постройте диаграмму, которая показывает зависимость **медианной** желаемой заработной платы (**"ЗП (руб)"**) от уровня образования (**"Образование"**). Используйте для диаграммы данные о резюме, где желаемая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по представленной диаграмме: для каких уровней образования наблюдаются наибольшие и наименьшие уровни желаемой заработной платы? Как вы считаете, важен ли признак уровня образования при прогнозировании заработной платы?*

# %%
hh_croped = hh_merged[hh_merged['ЗП (руб)'] < 1000000]
salary_db = hh_croped.groupby('Образование')['ЗП (руб)'].median()
#display(salary_db)

fig = plt.figure(figsize=(13, 4))
main_axes = fig.add_axes([0, 0, 1, 1])
main_axes.bar(x = salary_db.index, height = salary_db);
main_axes.set_ylabel('Размер медианной желаемой заработной платы в руб.');
main_axes.set_xlabel('Уровень образования');
main_axes.set_title('Зависимость медианной желаемой заработной платы от уровня образования');

# %% [markdown]
# Анализируя столбчатую диаграмму зависимости медианной желаемой заработной платы от уровня образования, можно сделать следующие выводы. Наибольший размер медианной желаемой заработной платы наблюдается у высшего уровня образования и составляет 60 тыс. руб., а наименьший размер медианной желаемоей заработной платы наблюдается у двух уровней образования - у среднего и среднего специального образования, - и составляет 40 тыс. руб. Я считаю, что уровень образования является важным признаком среди прочих иных при прогнозировании заработной платы, т.к. он не только является одним из факторов размера заработной платы, но и, как правило, предопределяет квалификацию, уровень подготовки, навыков и способностей соискателя.

# %% [markdown]
# 5). Постройте диаграмму, которая показывает распределение желаемой заработной платы (**"ЗП (руб)"**) в зависимости от города (**"Город"**). Используйте для диаграммы данные о резюме, где желая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по полученной диаграмме: как соотносятся медианные уровни желаемой заработной платы и их размах в городах? Как вы считаете, важен ли признак города при прогнозировании заработной платы?*

# %%
hh_croped = hh_merged[hh_merged['ЗП (руб)'] < 1000000]

fig = px.box(
    data_frame=hh_croped,
    x='ЗП (руб)',
    y='Город',
    title='Коробчатая диаграмма распределения размера зарплаты в рублях в зависимости от города'
)
fig.show()

# %% [markdown]
# Анализируя коробчатую диаграмму распределения желаемой заработной платы в рублях в зависимости от города, можно сделать следующие выводы.
# Так, наибольшая медиана и наибольший размах, размер ящика, желаемой зарплаты наблюдается в городе Москве: медиана равна 85 тыс., а q25 и q75 соответственно равны 60 тыс. руб. и 150 тыс. руб. Такой результат ожидаем и логичен. Москва - столица России и её экономический центр. Зарплаты в Москве статистически самые высокие, и вместе с тем велик разброс этих величин вследсвие различных профессий, сфер экономики и занятости.
# Несколько меньшая медианная желаемая зарплата в размере 60 тыс.руб. и меньший размах (q25=45 тыс.руб. и q75=85 тыс.руб.) отмечаются в Санкт-Петербурге. Культурная столица России отличается меньшим экономическим оборотом и более спокойной деловой активностью, что обусловливает данную статистику.
# Наименьшая медиана, равная 40 тыс.руб., и меньший межквартильный размах желаемых заработных плат, для которого q25=30 тыс.руб. и q75=60 тыс.руб, наблюдается как в городах-миллионниках, так и в "других" городах.
# В целом, признак города предопределяет уровень желаемой заработной платы в зависимости от того или иного города. Так, например, в Москве данный показатель наибольший. Однако визуальный анализ демонстрирует одинаковые результаты для городов, отличающихся от Москвы и Санкт-Петербурга. Таким образом, признак города имеет определенную важность при прогнозировании заработной платы, но при этом не является первоочередным.

# %% [markdown]
# 6). Постройте **многоуровневую столбчатую диаграмму**, которая показывает зависимость медианной заработной платы (**"ЗП (руб)"**) от признаков **"Готовность к переезду"** и **"Готовность к командировкам"**. Проанализируйте график, сравнив уровень заработной платы в категориях.

# %%
fig = plt.figure(figsize=(10, 7))

hh_croped = hh_merged.groupby(['Готовность к переезду','Готовность к командировкам'], as_index=False)['ЗП (руб)'].median()
#display(hh_croped)

barplot = sns.barplot(
    data=hh_croped,
    x='Готовность к переезду',
    y='ЗП (руб)',
    hue='Готовность к командировкам',
)
barplot.set_title('Зависимость медианной ЗП от готовности к переезду и готовности к командировкам');

# %% [markdown]
# Анализируя многоуровневую столбчатую диаграмму, которая показывает зависимость медианной заработной платы от признаков "Готовность к переезду" и "Готовность к командировкам", можно сделать следующие выводы.
# Наименьшая желаемая медианная заработная плата в размере 40 тыс.руб. отмечается у соискателей, которые не готовы к переезду и не готовы к командировкам. Медианная зараплата в размере 50 тыс.руб. регистрируется у соискателей, готовых к переезду, но не готовых к командировкам.
# Готовность к командировкам, как видно из графика положительно влияет на размер желаемой заработной платы. Так, соискатели, готовые к командировкам и не готовые к переезду, претендуют на медианную зарплату, равную 60 тыс.руб. И если соискатель готов как командировкам, так и к переезду, то такая медианная заработная плата составляет максимальную величину среди анализируемых категорий и равна приблизительно 66 тыс.руб.
# Таким образом, готовность к командировкам и готовность к переезду повышаеют медианную желаемую заработную плату, причем наибольшая величина регистрируется у тех, кто готов и переехать, и ездить в командировки.

# %% [markdown]
# 7). Постройте сводную таблицу, иллюстрирующую зависимость **медианной** желаемой заработной платы от возраста (**"Возраст"**) и образования (**"Образование"**). На полученной сводной таблице постройте **тепловую карту**. Проанализируйте тепловую карту, сравнив показатели внутри групп.

# %%
pivot = hh_merged.pivot_table(
    values='ЗП (руб)',
    columns='Возраст',
    index='Образование',
    aggfunc='median', 
    
)
pivot.columns = pivot.columns.astype('string')
#display(pivot)

heatmap = sns.heatmap(data=pivot, cmap='YlGnBu', annot=False)
heatmap.set_title('Тепловая карта зависимости медианной заработной платы от возраста и образования', fontsize=16);

# %% [markdown]
# Анализируя тепловую карту зависимости медианной заработной платы от возраста и образования, можно сделать следующие выводы. Чем темнее ячейка, тем выше уровень желаем заработной платы. Чем быстрее полоса переходит от светло-желтого к темно-синему цвету, тем быстрее карьерный рост и интенсивнее рост желаемой заработной платы. Белые "пятна" означают пропуски в данных, их отсутсвие.
# Так, среднее специальное образование отличается очень медленным и слабым ростом заработной платы - полоса едва темнеет до уровня примерно 60 тыс.руб (если игнорировать темно-синий выброс в возрасте 67 лет). В интервале примерно с 25 до 47 наблюдается наибольшее затемнение.
# Средний уровень образования также характеризуется слабым затемнением, а значит и слабым приростом заработной платы, хотя ее интенсивность роста выше чем у среднего специального уровня - в возрасте 17-25 лет ячейки сравнительно темнее и соответствуют примерно 49 тыс.руб. Наиболее темные ячейки отмечаются в возрасте приблизительно 33-34, 40, 41, 48 годах и равны приближенно 60-70 тыс.руб. Также на графике визуализируется темно-синяя ячейка, соответствующая уровню зарплаты 120 тыс.руб. и выше, в возрасте примерно 56 лет (данная ячейка явно выбивается из колеи и может быть потенциальным выбросом).
# Неоконченное высшее образование затемняется еще быстрее и интенсивнее чем предыдущие уровни образования. И примерно к 35-40 годам медианная желаемая заработная плата достигает размера 60 тыс.руб. А в возрасте 40-47 лет она и вовсе превышает 80 тыс.руб. Также выделяется темно-синяя ячейка в возрасте 57-58 лет.
# И в завершении тепловая карта вышего образования демонстирует самый быстрый и интенсивный рост медианной желаемой заработной платы. Так, начиная с 18 лет заработная плата растет с 30 тыс.руб. до 40-45 лет до уровня 80-100 тыс.руб. И снова визуально определяются выбросы с зарплатой, превышающей 120 тыс.руб. в 16 лет, 90 тыс.руб. в 17 лет и свыше 100 тыс.руб. в 69-70 лет.
# Итак, самый быстрый карьерный рост и наибольшая интенсивность роста заработной платы отмечается у высшего уровня образования.

# %% [markdown]
# 8). Постройте **диаграмму рассеяния**, показывающую зависимость опыта работы (**"Опыт работы (месяц)"**) от возраста (**"Возраст"**). Опыт работы переведите из месяцев в года, чтобы признаки были в едином масштабе. Постройте на графике дополнительно прямую, проходящую через точки (0, 0) и (100, 100). Данная прямая соответствует значениям, когда опыт работы равен возрасту человека. Точки, лежащие на этой прямой и выше нее - аномалии в наших данных (опыт работы больше либо равен возрасту соискателя)

# %%
hh_croped = hh_merged[['Опыт работы (месяц)', 'Возраст']]
hh_croped['Опыт работы (год)'] = hh_croped['Опыт работы (месяц)'] / 12
#display(hh_croped)

fig = plt.figure(figsize=(10, 7))
sns.lineplot(x=[0, 100], y=[0,100])
scatterplot = sns.scatterplot(
    data=hh_croped,
    x='Возраст',
    y='Опыт работы (год)',
)
scatterplot.set_title('Зависимость опыта работы от возраста');

hh_croped_filter = hh_croped[hh_croped['Опыт работы (год)'] > hh_croped['Возраст']] # таблица с наблюдениями, лежащими выше прямой
display(hh_croped_filter)
# Out:
# <ipython-input-20-1e9b2d7b41cf>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        Опыт работы (месяц)  Возраст  Опыт работы (год)
# 4535                 271.0       18          22.583333
# 19351                470.0       28          39.166667
# 19872                416.0       34          34.666667
# 26477                411.0       34          34.250000
# 29098                477.0       14          39.750000
# 40015               1188.0       48          99.000000
# 43451                434.0       36          36.166667

# %% [markdown]
#  Анализируя диаграмму рассеяния, показывающую зависимость опыта работы (в годах) от возраста, можно сделать следующие выводы.
#  Безусловно, большая часть наблюдей лежит ниже прямой, проходящей через точки (0, 0) и (100, 100), что логично, ведь опыт работы должен быть меньше возраста соискателя. Также можно заметить положительный тренд роста - с увеличением возраста растет и опыт работы, что также весьма естественно. Вместе с этим на графике также можно увидеть точки, соответствующие большому возрасту и малому опыту работы. Например, точки в интервале 40-60 лет близ нулевого опыта.
#  Отдельного внимания заслуживают точки, находящиеся на прямой и даже выше неё. Очевидно, что опыт работы никак не может быть больше возраста работника. Следовательно, данные наблюдения являются аномалиями и подлежат удалению.

# %% [markdown]
# **Дополнительные баллы**
#
# Для получения 2 дополнительных баллов по разведывательному анализу постройте еще два любых содержательных графика или диаграммы, которые помогут проиллюстрировать влияние признаков/взаимосвязь между признаками/распределения признаков. Приведите выводы по ним. Желательно, чтобы в анализе участвовали признаки, которые мы создавали ранее в разделе "Преобразование данных".

# %% [markdown]
# 9). Дополнительный график №1

# %%
hh_croped = hh_merged.groupby('Пол')['ЗП (руб)'].median()
#display(hh_croped)

fig = plt.figure(figsize=(13, 4))
main_axes = fig.add_axes([0, 0, 1, 1])
main_axes.bar(x = hh_croped.index, height = hh_croped);
main_axes.set_ylabel('Медианная желаемая зароботная плата');
main_axes.set_title('Соотношение медианной заработоной платы в зависимости от пола');

# %% [markdown]
# Анализируя столбчатую диаграмму зависимости медианной заработной платы от пола, можно сделать следующий вывод. Запрашиваемая заработная плата больше у мужчин чем у женщин и составляет 60 тыс.руб. против 48 тыс.руб. Такой результат отражает текущие социо-культурные и социо-экономические тенденции и предпосылки.

# %% [markdown]
# 10). Дополнительный график №2

# %%
hh_croped = hh_merged.groupby(['полная занятость', 'удаленная работа'], as_index=False)['ЗП (руб)'].median()
#display(hh_croped)

barplot = sns.barplot(
    data=hh_croped,
    x='полная занятость',
    y='ЗП (руб)',
    hue='удаленная работа',
)
barplot.set_title('Зависимость медианной заработной платы от полной занятости и удаленной работы');

# %% [markdown]
# Анализируя многоуровневую столбчатую диаграмму зависимости размера медианной желаемой заработной платы от факторов полной занятости и удаленной работы, можно сделать следующие выводы.
# Учитывая, что удаленная работа приобрела особую популярность в последние годы, интересно пронаблюдать ее влияние на размер желаемой заработной платы в зависимости полной занятости. Так, при неполной занятости, которая может быть как частичной, так и проектной, волтерством или даже стажировкой, факт удаленной работы не влияет на размер зараплаты. Её медианная величина составляет 30 тыс.руб. Такой результат весьма логичен, ведь неполная занятость предполагает меньшую загруженность по часам работы, по степени ответственности и сложности работы, по степени интенсивности труда и т.д. Напротив, при полной занятости медианная заработная плата выше для удаленной работы. Её размер равен 60 тыс.руб., когда как зарплата при полной занятости не на удаленке составляет 55 тыс.руб. Хоть разрыв и не столь велик, но факт того, что удаленщики запрашивают заработную плату больше, чем  для "работы в офисе", весьма любопытен и интересен. Ведь на первый взгляд, удаленщикам требуется меньше расходов в сравнении с теми, кто ездит на работу. Например, они не затрачивают денежные средства на каждодневный маршрут в офис на общественном транспорте (проездной билет) или же на личном автомобиле (бензин). Однако также есть вероятно того, что не всех удаленщиков работодатели оснащают необходимыми средствами труда, например ноутбуками, и, запрашивая большую зарплату, они тем самым пытаются компенсировать личные расходы на такие приобретения.

# %% [markdown]
# # Очистка данных

# %% [markdown]
# 1). Начнем с дубликатов в наших данных. Найдите **полные дубликаты** в таблице с резюме и удалите их.

# %%
mask = hh_merged.duplicated()
hh_duplicates = hh_merged[mask]
print(f'Изначальное число записей: {hh_merged.shape[0]}')
print(f'Число найденных дубликатов: {hh_duplicates.shape[0]}')

hh_dedupped = hh_merged.drop_duplicates() # создадим новую, очищенную от дубликатов, таблицу 
print(f'Результирующее число записей: {hh_dedupped.shape[0]}')
# Out:
# Изначальное число записей: 44744
# Число найденных дубликатов: 161
# Результирующее число записей: 44583

# %% [markdown]
# 2). Займемся пропусками. Выведите информацию **о числе пропусков** в столбцах.

# %%
cols_null_count = hh_dedupped.isnull().sum()
cols_with_null = cols_null_count[cols_null_count>0].sort_values(ascending=False)
display(cols_with_null)
# Out:
# currency                           42312
# per                                42312
# date                               42312
# time                               42312
# vol                                42312
# Опыт работы (месяц)                  168
# Последняя/нынешняя должность           2
# Последнее/нынешнее место работы        1
# dtype: int64

# %% [markdown]
# 3). Итак, у нас есть пропуски в 3ех столбцах: **"Опыт работы (месяц)"**, **"Последнее/нынешнее место работы"**, **"Последняя/нынешняя должность"**. Поступим следующим образом: удалите строки, где есть пропуск в столбцах с местом работы и должностью. Пропуски в столбце с опытом работы заполните **медианным** значением.

# %%
hh_drop = hh_dedupped.copy()
hh_drop = hh_drop.dropna(subset=['Последнее/нынешнее место работы', 'Последняя/нынешняя должность'])

hh_drop['Опыт работы (месяц)'] = hh_drop['Опыт работы (месяц)'].fillna(hh_drop['Опыт работы (месяц)'].median())
result = round(hh_drop['Опыт работы (месяц)'].mean())
print(f'Результирующее среднее значение в столбце "Опыт работы (месяц)" после заполнения пропусков равно {result} месяцам')
#display(hh_drop.isna().sum()) # проверка обработки пропусков
# Out:
# Результирующее среднее значение в столбце "Опыт работы (месяц)" после заполнения пропусков равно 114 месяцам

# %% [markdown]
# 4). Мы добрались до ликвидации выбросов. Сначала очистим данные вручную. Удалите резюме, в которых указана заработная плата либо выше 1 млн. рублей, либо ниже 1 тыс. рублей.

# %%
outliers = hh_drop[(hh_drop['ЗП (руб)'] > 1000000) | (hh_drop['ЗП (руб)'] < 1000)]
print(f'Количество выбросов в признаке "ЗП (руб)" равно {outliers.shape[0]} записям')
hh_cleaned = hh_drop.drop(outliers.index, axis=0)
print(f'Результирующее число записей: {hh_cleaned.shape[0]}')
# Out:
# Количество выбросов в признаке "ЗП (руб)" равно 89 записям
# Результирующее число записей: 44492

# %% [markdown]
# 5). В процессе разведывательного анализа мы обнаружили резюме, в которых **опыт работы в годах превышал возраст соискателя**. Найдите такие резюме и удалите их из данных

# %%
outliers = hh_cleaned[(hh_cleaned['Опыт работы (месяц)'] / 12) > hh_cleaned['Возраст']]
print(f'Количество выбросов в признаке "Опыт работы (месяц)" равно {outliers.shape[0]} записям')

hh_cleaned = hh_cleaned.drop(outliers.index, axis=0)
print(f'Результирующее число записей: {hh_cleaned.shape[0]}')
# Out:
# Количество выбросов в признаке "Опыт работы (месяц)" равно 7 записям
# Результирующее число записей: 44485

# %% [markdown]
# 6). В результате анализа мы обнаружили потенциальные выбросы в признаке **"Возраст"**. Это оказались резюме людей чересчур преклонного возраста для поиска работы. Попробуйте построить распределение признака в **логарифмическом масштабе**. В какую сторону **асимметрично логарифмическое распределение**? Напишите об этом в коммментарии. Найдите выбросы с помощью **метода z-отклонения** и удалите их из данных, используйте логарифмический масштаб, сделайте **послабление на 1 сигму (возьмите 4 сигмы)** в сторону, противоположную асимметрии.

# %%
log_age = np.log(hh_cleaned['Возраст'] + 1)

fig = plt.figure(figsize=(15, 4))
axes = fig.add_axes([0, 0, 1, 1])
histplot = sns.histplot(
    data=log_age,
    bins=30,
);
histplot.set_ylabel('Частота');
histplot.set_title('Распределение признака "Возраст" в логарифмическом масштабе');

mu = log_age.mean()
sigma = log_age.std()
lower_bound = mu - 3 * sigma
upper_bound = mu + 3 * sigma

histplot.axvline(log_age.mean(), color='k', lw=2)
histplot.axvline(lower_bound, color='k', ls='--', lw=2)
histplot.axvline(upper_bound, color='k', ls='--', lw=2)

print(f'Численный показатель асимметрии равен {round(log_age.skew(), 2)}')

def outliers_z_score_mod(data, feature, log_scale=False, left=3, right=3):
    """Функция реализует алгоритм метода z-отклонений (метод сигм)

    Args:
        data ([DataFrame]): DataFrame по которому ищутся выбросы
        feature ([Series]): Признак, по которому ищутся выбросы
        log_scale (bool, optional): Возможность работы в логарифмическом масштабе. Defaults to False.
        left (int, optional): Параметр левой границы. Defaults to 3.
        right (int, optional): Параметр правой границы. Defaults to 3.

    Returns:
        outliers ([dataframe]): DataFrame с выбросами
        cleaned ([dataframe]): DataFrame, очищенный от выбросов
        
    """

    if log_scale:
        x = np.log(data[feature]+1)
    else:
        x = data[feature]
    mu = x.mean()
    sigma = x.std()
    lower_bound = mu - left * sigma
    upper_bound = mu + right * sigma
    outliers = data[(x < lower_bound) | (x > upper_bound)]
    cleaned = data[(x > lower_bound) & (x < upper_bound)]
    return outliers, cleaned

outliers, cleaned = outliers_z_score_mod(hh_cleaned, 'Возраст', log_scale=True, left=3, right=4)
print(f'Число выбросов по методу z-отклонения: {outliers.shape[0]}')
print(f'Результирующее число записей: {cleaned.shape[0]}')
display(outliers)

hh_final_database = cleaned
#display(hh_final_database)
# Out:
# Численный показатель асимметрии равен 0.47
# Число выбросов по методу z-отклонения: 3
# Результирующее число записей: 44482
#             Ищет работу на должность:  \
# 31137  Менеджер по работе с клиентами
# 32950                 Тестировщик игр
# 33654            Frontend-разработчик
#
#                             Город, переезд, командировки  \
# 31137  Санкт-Петербург , не готов к переезду , не гот...
# 32950  Канск , не готов к переезду , не готов к коман...
# 33654  Санкт-Петербург , не готов к переезду , готов ...
#
#       Последнее/нынешнее место работы    Последняя/нынешняя должность  \
# 31137           ООО "ФёрстКэшКомпани"  Менеджер по работе с клиентами
# 32950                        OOO ЖМЫХ                  Тестировщик ПО
# 33654                       Freelance            Frontend-разработчик
#
#       Обновление резюме        Авто          Образование Пол  Возраст  \
# 31137        2019-06-04  Не указано              среднее   М       15
# ...

# %% [markdown]
# Логарифмическое распределение признака "Возраст" имеет правостороннюю асимметрию, так как среднее значение, жирная вертикальная линия, находится правее моды, самого высокого столбика. Также метод skew() возвращает положительное значение асимметрии, равное 0.47.
#
# Оценивая данные, представленные в таблице с полученными выбросами, можно сделать вывод, что под категорию выбросов с учётом "послебления" на 1 сигму в правую сторону попадают соискатели в возрасте 15 и 100 лет.
